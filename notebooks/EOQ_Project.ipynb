# %% [markdown]
# # Inventory Optimization in E-commerce with the EOQ Model
# ## Derivation, Implementation, and Simulation
#
# **Author:** Nikolina Krasteva
# **Course:** Math for Dev
# **Date:** [...]
#
# ### Project Summary
# This project studies the Economic Order Quantity (EOQ) model for inventory optimization in e-commerce. The goal is to derive the model mathematically, implement it in Python, and validate it through simulation without using real datasets.

# %% [markdown]
# ## 1. Introduction
#
# Inventory management is a central operational problem in e-commerce. Businesses must decide how much inventory to order and keep in stock in order to satisfy customer demand while controlling costs.
#
# A key trade-off in inventory decisions is the balance between:
#
# - **Ordering cost**: the cost incurred each time an order is placed
# - **Holding cost**: the cost of storing inventory over time
#
# If a business places orders too frequently, ordering costs increase. If it orders too much inventory at once, holding costs increase. The challenge is to determine an order quantity that balances these competing costs.
#
# ### Project Goal
#
# The goal of this project is to study and implement the **Economic Order Quantity (EOQ)** model, a classical mathematical model for inventory optimization.
#
# The project includes:
# 1. Mathematical formulation of the inventory cost problem
# 2. Analytical derivation of the EOQ formula
# 3. Python implementation of the model
# 4. Numerical verification through simulation
# 5. Sensitivity analysis and discussion of limitations
#
# ### Scope of the Project
#
# This project focuses on **mathematical modeling and simulation** rather than real-world data analysis. No real dataset is used. The objective is to demonstrate how a mathematical optimization model can be translated into clear and testable Python code.

# %% [markdown]
# ## 2. Problem Formulation
#
# We consider a single-product inventory system in an e-commerce setting and define the following variables:
#
# - $D$: annual demand (units per year)
# - $Q$: order quantity (units per order)
# - $S$: ordering cost per order
# - $H$: holding cost per unit per year
#
# The objective is to determine the value of $Q$ that minimizes the total annual inventory-related cost.
#
# ### Cost Components
#
# #### 1. Ordering Cost (per year)
#
# If the annual demand is $D$ and each order contains $Q$ units, then the number of orders placed per year is:
#
# $$
# \frac{D}{Q}
# $$
#
# Since each order costs $S$, the total annual ordering cost is:
#
# $$
# \text{Ordering Cost}(Q) = \frac{D}{Q}S
# $$
#
# #### 2. Holding Cost (per year)
#
# Under the classical EOQ assumptions, inventory decreases linearly from $Q$ to $0$ between replenishments. Therefore, the average inventory level is:
#
# $$
# \frac{Q}{2}
# $$
#
# If the holding cost per unit per year is $H$, then the total annual holding cost is:
#
# $$
# \text{Holding Cost}(Q) = \frac{Q}{2}H
# $$
#
# ### Total Cost Function
#
# The total annual cost is the sum of the ordering and holding costs:
#
# $$
# TC(Q) = \frac{D}{Q}S + \frac{Q}{2}H
# $$
#
# ### Optimization Objective
#
# We seek the optimal order quantity $Q^* > 0$ such that:
#
# $$
# Q^* = \arg\min_{Q > 0} TC(Q)
# $$
#
# In the next section, this optimization problem will be solved analytically.
